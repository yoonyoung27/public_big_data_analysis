# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonyoung27/public_big_data_analysis/blob/main/%EC%97%B0%EC%98%A4_ch06(%EC%A1%B0%EA%B1%B4%EB%AC%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #흐름 제어

# %% [markdown]
# ###① 선택(if문)
# ![image.png](data:image/png;base64,...)
#
# * 설정하려는 조건 집합의 개수와 범위에 따라 elif와 else 생략 가능

# %%
print('1. 일요일 낮의 날씨를 입력해주세요 : ')
날씨 = input()

if 날씨 == '비':
    print('집에서 프로그램을 만들자.')
if 날씨 != '비':
    print('공원에서 스케이트보드를 타자.')

#if 날씨 == '비':
#    print('집에서 프로그램을 만들자.')
#else:
#    print('공원에서 스케이트보드를 타자.') ; 위와 같은 식

def ftn1():
    print('2. 일요일 낮의 기온을 입력해주세요 : ')
    기온 = float(input())
    if 28.0<=기온:
        print('바닷가에서 더위를 피하자.')
    elif 16.0<=기온:
        print('공원에서 스케이트보드를 타자.')
    elif 8.0<=기온:
        print('도서관에서 책을 읽자.')
    else:
        print('집에서 프로그램을 만들자.')

def ftn2():
    print('3. 일요일 낮의 기온을 입력해주세요 : ')
    기온 = float(input())
    if 28.0<=기온:
        print('바닷가에서 더위를 피하자.')
    if 16.0<=기온:
        print('공원에서 스케이트보드를 타자.')
    if 8.0<=기온:
        print('도서관에서 책을 읽자.')
    else:
        print('집에서 프로그램을 만들자.')

print('')
ftn1()
print('')
ftn2()
# Out:
# 1. 일요일 낮의 날씨를 입력해주세요 :
# 비
# 집에서 프로그램을 만들자.
#
# 2. 일요일 낮의 기온을 입력해주세요 :
# 17.0
# 공원에서 스케이트보드를 타자.
#
# 3. 일요일 낮의 기온을 입력해주세요 :
# 17.0
# 공원에서 스케이트보드를 타자.
# 도서관에서 책을 읽자.

# %% [markdown]
# * else와 elif 조건 집합의 범위에 주의한다

# %%
날씨='비'
if 날씨 == '비':
    pass
else:
    print('공원에서 스케이트보드를 타자.')

#if not (날씨 == '비'):
#    print('공원에서 스케이트 보드를 타자.') ; 위와 같은 식

# %% [markdown]
# * pass를 사용하여 if문의 본문을 생략할 수 있다

# %% [markdown]
# ####\* 조건부 식
# 조건부 식을 이용하여 계산 결과를 변수에 대입한다
#
# ![image.png](data:image/png;base64,...)

# %%
요일 = '화요일'

가격 = 1000 if 요일 == '월요일' else 2500
가격

#if 요일 == '월요일':
#    가격 = 1000
#else:
#    가격 = 2500 ; 위와 같은 식
# Out:
# 2500

# %% [markdown]
# ###② 반복

# %% [markdown]
# ####②.1 while 문
#
# ![image.png](data:image/png;base64,...)

# %%
text = """아무 메시지나 입력하세요. 그만하려면 '그만'을 입력하세요."""
while text!='그만':
    print('컴퓨터 : ' + text)
    text=input()
# Out:
# 컴퓨터 : 아무 메시지나 입력하세요. 그만하려면 '그만'을 입력하세요.
# 안녕?
# 컴퓨터 : 안녕?
# 따라하지마
# 컴퓨터 : 따라하지마
# 그만

# %% [markdown]
# #####\* while문 형식
# * N회 반복
#
# ![image.png](data:image/png;base64,...)
#
# * 무한 반복
#
# ![image.png](data:image/png;base64,...)

# %%
i=0
while i<3:
    print('안녕')
    i+=1

#while 1:
#    print('안녕하세요') ; 무한 반복
# Out:
# 안녕
# 안녕
# 안녕

# %% [markdown]
# ####②.2 for 문
#
# ![image.png](data:image/png;base64,...)

# %%
rainbow = ['Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Indigo', 'Violet']
for color in rainbow:
    print(color)

print('')
a = [(1,2),(3,4),(5,6)]
for (first, last) in a:
    print(first+last)
# Out:
# Red
# Orange
# Yellow
# Green
# Blue
# Indigo
# Violet
#
# 3
# 7
# 11

# %% [markdown]
# #####\* for문 형식
#
# ![image.png](data:image/png;base64,...)

# %%
print('몇 번 반복하시겠습니까?')
n=int(input())

for _ in range(n):
    print('안녕')
# Out:
# 몇 번 반복하시겠습니까?
# 3
# 안녕
# 안녕
# 안녕

# %%
total=0

while True:
    print('더할 수를 입력하세요 : ', end='')
    user_input=input()
    
    if user_input=='그만':
        break

    if not user_input.isnumeric():
        print('잘못된 입력입니다.')
        continue

    total += int(user_input)
    print('합계 : ', total)

print('프로그램을 종료합니다.')
# Out:
# 더할 수를 입력하세요 : 500
# 합계 :  500
# 더할 수를 입력하세요 : 안녕
# 잘못된 입력입니다.
# 더할 수를 입력하세요 : 1000
# 합계 :  1500
# 더할 수를 입력하세요 : 그만
# 프로그램을 종료합니다.

# %% [markdown]
# * continue와 break를 사용하여 반복문의 본문을 생략할 수 있다
#
# ![image.png](data:image/png;base64,...)

# %%
def 첫_짝수_찾기(numbers):
    """numbers에서 첫 번째 짝수를 찾아 화면에 출력한다."""
    for n in numbers:
        if n%2==0:
            print(n, '이 첫 짝수 입니다.')
            break;
    else:
        print('짝수가 없습니다.')
    
첫_짝수_찾기([1,3,5,33,47,55])
첫_짝수_찾기([7,5,6,72,19,81])
# Out:
# 짝수가 없습니다.
# 6 이 첫 짝수 입니다.

# %% [markdown]
# * else를 사용하여 반복 조건 집합의 여집합에 대하여 코드를 작성할 수 있다
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####②* try문

# %%
while True:
    try:
        print('0이 아닌 정수를 입력해 주세요 :', end=' ')
        user_number = int(input())
        result = 1/user_number
    except ZeroDivisionError:
        print('0으로 나눌 수 없습니다.')
    except ValueError:
        print('입력한 값은 정수가 아닙니다.')
    else:
        print(result)
        break
# Out:
# 0이 아닌 정수를 입력해 주세요 : 0
# 0으로 나눌 수 없습니다.
# 0이 아닌 정수를 입력해 주세요 : 정수
# 입력한 값은 정수가 아닙니다.
# 0이 아닌 정수를 입력해 주세요 : 5
# 0.2
